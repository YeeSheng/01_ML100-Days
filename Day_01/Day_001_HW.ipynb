# %% [markdown]
# ## Day1 Homework作業

# %% [markdown]
# # 作業一： 找一組資料，並回答下列問題

# %%
import pandas as pd
import os
import requests
import io

# %%
url = 'https://raw.githubusercontent.com/YeeSheng/ML100-Days/master/Day_01/BlackFriday.csv' ##不能直接從www.github.com//xxx下載，要從他的raw下載
BF = requests.get(url).content
c=pd.read_csv(io.StringIO(BF.decode("utf-8")))

# %% [markdown]
# ### Q1.你選的這組資料為何重要?
# Ans.這組資料是黑色星期五的消費資料，其中記錄了消費者的性別、年齡、職
#     業、居住地區、購買商品等
#
# ### Q2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)?
# Ans.此資料是一組大學學生由一家大型超市向消費者所收集的資料，資料時間
#     約莫是107年7月
#
# ### Q3. 蒐集而來的資料型態為何?
# Ans.如下所示，資料有數值（both qualitative and quantitative）和文字
#     值，有些欄位有缺失值。
#
# ### Q4. 這組資料想解決的問題如何評估?
# Ans.此問題應該是為了尋找消費意願以及消費者的關係。因此我認為除了觀察
#     Purchase與其他參數的相關性之外，還可以根據消費者的地區，性別等與購
#     買產品的category做關聯性分析，求出其信心值等。

# %%
print(c.head())
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %% [markdown]
# # 作業2
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ### Q1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)?
# Ans.如何定義“提升業績”？業績應該說是車隊所賺的錢，錢賺的多有兩個方
#     法：客人數量變多，或者每個客人多給錢，或者成本降低使得盈餘變多。
#     那這些與什麼有關呢？我們從直覺上可以知道也許可以收集每個司機的資
#     料，每一輛載客車的資料，每個顧客的資料，以及在載客地點等等這些都可
#     能會有影響。如果能夠簡單的將顧客以及司機分類可能就可以達到更好的業
#     績成果
#
# ### Q2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)?
# Ans.司機以及載客車的資料我們可以預先收集，接著可以經由電話叫車APP收集
#     用戶資料，再接著使用定位系統收集載客的地區。如果是現場叫車的，則由
#     司機自行判斷并登錄資料
#
# ### Q3. 蒐集而來的資料型態為何?
# Ans. 時間、文字和數字型態
#
# ### Q4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)?
# Ans.
# 1，驗證相同的情況發生過幾次（好比，女生，16歲，西門町上車，下午8點）而下午8點女生上車的幾率是多少等等。計算信心度以及支持度。
# 2，結果論。將實行新策略的新業績量，與前幾個月的業績量相比較，觀察收入是否增加。

# %% [markdown]
# # 作業3
# ### 練習時間
# 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):    
    MSE=(np.sum((y-yp)**2)/len(y));
    return MSE

# %%
m = 1
c = 0
N = 1000
x = np.linspace(0, N-1, N)

y = m*np.sin((x/(10*np.pi))+np.random.randn(N)/np.pi)+c

plt.plot(x, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = m*np.sin(x/(10*np.pi))+c
plt.plot(x, y, 'b.', label = 'data')
plt.plot(x, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
np.shape((y-y_hat)**2)
# Out:
# (1000,)

# %%
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 0.051
